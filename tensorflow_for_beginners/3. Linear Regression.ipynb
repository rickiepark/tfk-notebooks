# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf

# %%
sess = tf.Session()

# %%
x_raw = tf.random_normal([1000], mean=0, stddev=0.55)
x = sess.run(x_raw)

# %%
y_raw = 0.1 * x + 0.3 + tf.random_normal([1000], mean=0, stddev=0.03)
y = sess.run(y_raw)

# %%
plt.plot(x, y, 'o', markeredgecolor='k')

# %%
W = tf.Variable(tf.zeros([1]))
b = tf.Variable(tf.zeros([1]))
y_hat = W * x + b

# %%
loss = tf.losses.mean_squared_error(y, y_hat)
optimizer = tf.train.GradientDescentOptimizer(0.5)
train = optimizer.minimize(loss)

# %%
init = tf.global_variables_initializer()
sess.run(init)

# %%
costs = []
for step in range(10):
    _, w_, b_, c = sess.run([train, W, b, loss])
    costs.append(c)
    print(step, w_, b_, c)
    # 산포도 그리기
    plt.plot(x, y, 'o', markeredgecolor='k')
    # 직선 그리기
    plt.plot(x, w_ * x + b_)
    # x, y 축 레이블링을 하고 각 축의 최대, 최소값 범위를 지정합니다.
    plt.xlabel('x')
    plt.xlim(-2,2)
    plt.ylim(0.1,0.6)
    plt.ylabel('y')
    plt.show()
# Out:
# 0 [ 0.034216] [ 0.29878271] 0.0935783
# 1 [ 0.05648145] [ 0.29871419] 0.00239514
# 2 [ 0.07135952] [ 0.29866964] 0.00156812
# 3 [ 0.08130123] [ 0.29863986] 0.00119885
# 4 [ 0.0879444] [ 0.29861999] 0.00103396
# 5 [ 0.09238346] [ 0.29860669] 0.00096034
# 6 [ 0.09534969] [ 0.29859781] 0.000927468
# 7 [ 0.09733176] [ 0.29859185] 0.00091279
# 8 [ 0.09865621] [ 0.29858789] 0.000906236
# 9 [ 0.09954122] [ 0.29858524] 0.00090331

# %%
plt.plot(costs)
